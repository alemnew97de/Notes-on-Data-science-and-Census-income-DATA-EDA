# %%
import pandas as pd
pd.read_csv(r"C:\Users\alemnew\Desktop\adult.test.csv.csv")
# Out:
#        |1x3 Cross validator     work-class  final-weight-estimate  \
# 0                        25        Private                 226802
# 1                        38        Private                  89814
# 2                        28      Local-gov                 336951
# 3                        44        Private                 160323
# 4                        18              ?                 103497
# ...                     ...            ...                    ...
# 16276                    39        Private                 215419
# 16277                    64              ?                 321403
# 16278                    38        Private                 374983
# 16279                    44        Private                  83891
# 16280                    35   Self-emp-inc                 182148
#
#            education  education-num       marital-status          occupation  \
# 0               11th              7        Never-married   Machine-op-inspct
# ...

# %%
#data cleaning using pandas

# %%
dataset=pd.read_csv(r"C:\Users\alemnew\Desktop\adult.test.csv.csv")

# %%
dataset
# Out:
#        |1x3 Cross validator     work-class  final-weight-estimate  \
# 0                        25        Private                 226802
# 1                        38        Private                  89814
# 2                        28      Local-gov                 336951
# 3                        44        Private                 160323
# 4                        18              ?                 103497
# ...                     ...            ...                    ...
# 16276                    39        Private                 215419
# 16277                    64              ?                 321403
# 16278                    38        Private                 374983
# 16279                    44        Private                  83891
# 16280                    35   Self-emp-inc                 182148
#
#            education  education-num       marital-status          occupation  \
# 0               11th              7        Never-married   Machine-op-inspct
# ...

# %%
dataset.head()
# Out:
#    |1x3 Cross validator  work-class  final-weight-estimate      education  \
# 0                    25     Private                 226802           11th
# 1                    38     Private                  89814        HS-grad
# 2                    28   Local-gov                 336951     Assoc-acdm
# 3                    44     Private                 160323   Some-college
# 4                    18           ?                 103497   Some-college
#
#    education-num       marital-status          occupation realtionship  \
# 0              7        Never-married   Machine-op-inspct    Own-child
# 1              9   Married-civ-spouse     Farming-fishing      Husband
# 2             12   Married-civ-spouse     Protective-serv      Husband
# 3             10   Married-civ-spouse   Machine-op-inspct      Husband
# 4             10        Never-married                   ?    Own-child
#
#      race      sex  capital-gain  capital-loss  hourse-per-week  \
# ...

# %%
dataset.head(3)
# Out:
#    |1x3 Cross validator  work-class  final-weight-estimate    education  \
# 0                    25     Private                 226802         11th
# 1                    38     Private                  89814      HS-grad
# 2                    28   Local-gov                 336951   Assoc-acdm
#
#    education-num       marital-status          occupation realtionship  \
# 0              7        Never-married   Machine-op-inspct    Own-child
# 1              9   Married-civ-spouse     Farming-fishing      Husband
# 2             12   Married-civ-spouse     Protective-serv      Husband
#
#      race    sex  capital-gain  capital-loss  hourse-per-week  native-country  \
# 0   Black   Male             0             0               40   United-States
# 1   White   Male             0             0               50   United-States
# 2   White   Male             0             0               40   United-States
#
#     income
# 0   <=50K.
# 1   <=50K.
# 2    >50K.

# %%
dataset.tail(2)
# Out:
#        |1x3 Cross validator     work-class  final-weight-estimate   education  \
# 16279                    44        Private                  83891   Bachelors
# 16280                    35   Self-emp-inc                 182148   Bachelors
#
#        education-num       marital-status        occupation realtionship  \
# 16279             13             Divorced      Adm-clerical    Own-child
# 16280             13   Married-civ-spouse   Exec-managerial      Husband
#
#                       race    sex  capital-gain  capital-loss  \
# 16279   Asian-Pac-Islander   Male          5455             0
# 16280                White   Male             0             0
#
#        hourse-per-week  native-country   income
# 16279               40   United-States   <=50K.
# 16280               60   United-States    >50K.

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (16281, 15)

# %%
dataset.sample(2)
# Out:
#       |1x3 Cross validator  work-class  final-weight-estimate education  \
# 2257                    34   Local-gov                 112680   HS-grad
# 9865                    51     Private                 159015   HS-grad
#
#       education-num       marital-status         occupation realtionship  \
# 2257              9             Divorced      Other-service    Unmarried
# 9865              9   Married-civ-spouse   Transport-moving      Husband
#
#         race      sex  capital-gain  capital-loss  hourse-per-week  \
# 2257   White   Female             0             0               20
# 9865   White     Male             0             0               60
#
#       native-country   income
# 2257   United-States   <=50K.
# 9865   United-States   <=50K.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   |1x3 Cross validator   16281 non-null  int64
#  1   work-class             16281 non-null  object
#  2   final-weight-estimate  16281 non-null  int64
#  3   education              16281 non-null  object
#  4   education-num          16281 non-null  int64
#  5   marital-status         16281 non-null  object
#  6   occupation             16281 non-null  object
#  7   realtionship           16281 non-null  object
#  8   race                   16281 non-null  object
#  9   sex                    16281 non-null  object
#  10  capital-gain           16281 non-null  int64
#  11  capital-loss           16281 non-null  int64
#  12  hourse-per-week        16281 non-null  int64
#  13  native-country         16281 non-null  object
# ...

# %%
dataset.describe()
# Out:
#        |1x3 Cross validator  final-weight-estimate  education-num  \
# count          16281.000000           1.628100e+04   16281.000000
# mean              38.767459           1.894357e+05      10.072907
# std               13.849187           1.057149e+05       2.567545
# min               17.000000           1.349200e+04       1.000000
# 25%               28.000000           1.167360e+05       9.000000
# 50%               37.000000           1.778310e+05      10.000000
# 75%               48.000000           2.383840e+05      12.000000
# max               90.000000           1.490400e+06      16.000000
#
#        capital-gain  capital-loss  hourse-per-week
# count  16281.000000  16281.000000     16281.000000
# mean    1081.905104     87.899269        40.392236
# std     7583.935968    403.105286        12.479332
# min        0.000000      0.000000         1.000000
# 25%        0.000000      0.000000        40.000000
# 50%        0.000000      0.000000        40.000000
# ...

# %%
dataset.describe().T
# Out:
#                          count           mean            std      min  \
# |1x3 Cross validator   16281.0      38.767459      13.849187     17.0
# final-weight-estimate  16281.0  189435.677784  105714.907671  13492.0
# education-num          16281.0      10.072907       2.567545      1.0
# capital-gain           16281.0    1081.905104    7583.935968      0.0
# capital-loss           16281.0      87.899269     403.105286      0.0
# hourse-per-week        16281.0      40.392236      12.479332      1.0
#
#                             25%       50%       75%        max
# |1x3 Cross validator       28.0      37.0      48.0       90.0
# final-weight-estimate  116736.0  177831.0  238384.0  1490400.0
# education-num               9.0      10.0      12.0       16.0
# capital-gain                0.0       0.0       0.0    99999.0
# capital-loss                0.0       0.0       0.0     3770.0
# hourse-per-week            40.0      40.0      45.0       99.0

# %%
dataset.describe(include='all').T
# Out:
#                          count unique                  top   freq  \
# |1x3 Cross validator   16281.0    NaN                  NaN    NaN
# work-class               16281      9              Private  11210
# final-weight-estimate  16281.0    NaN                  NaN    NaN
# education                16281     16              HS-grad   5283
# education-num          16281.0    NaN                  NaN    NaN
# marital-status           16281      7   Married-civ-spouse   7403
# occupation               16281     15       Prof-specialty   2032
# realtionship             16281      6              Husband   6523
# race                     16281      5                White  13946
# sex                      16281      2                 Male  10860
# capital-gain           16281.0    NaN                  NaN    NaN
# capital-loss           16281.0    NaN                  NaN    NaN
# hourse-per-week        16281.0    NaN                  NaN    NaN
# ...

# %%
dataset.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16276    False
# 16277    False
# 16278    False
# 16279    False
# 16280    False
# Length: 16281, dtype: bool

# %%
dataset[dataset.duplicated()]
# Out:
#        |1x3 Cross validator     work-class  final-weight-estimate   education  \
# 864                      24        Private                 194630   Bachelors
# 11189                    37        Private                  52870   Bachelors
# 11212                    29        Private                  36440   Bachelors
# 13848                    30        Private                 180317   Assoc-voc
# 15960                    18   Self-emp-inc                 378036        12th
#
#        education-num       marital-status          occupation    realtionship  \
# 864               13        Never-married      Prof-specialty   Not-in-family
# 11189             13   Married-civ-spouse     Exec-managerial         Husband
# 11212             13        Never-married        Adm-clerical   Not-in-family
# 13848             11             Divorced   Machine-op-inspct   Not-in-family
# 15960              8        Never-married     Farming-fishing       Own-child
#
# ...

# %%
dataset['capital-gain']
# Out:
# 0           0
# 1           0
# 2           0
# 3        7688
# 4           0
#          ...
# 16276       0
# 16277       0
# 16278       0
# 16279    5455
# 16280       0
# Name: capital-gain, Length: 16281, dtype: int64

# %%
dataset['capital-gain'].head(20)
# Out:
# 0        0
# 1        0
# 2        0
# 3     7688
# 4        0
# 5        0
# 6        0
# 7     3103
# 8        0
# 9        0
# 10    6418
# 11       0
# 12       0
# 13       0
# 14    3103
# 15       0
# 16       0
# 17       0
# 18       0
# 19       0
# Name: capital-gain, dtype: int64

# %%
dataset['capital-gain'].shape
# Out:
# (16281,)

# %%
dataset['capital-gain'].dtype
# Out:
# dtype('int64')

# %%
dataset.income.str.isnumeric()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16276    False
# 16277    False
# 16278    False
# 16279    False
# 16280    False
# Name: income, Length: 16281, dtype: bool

# %%
~dataset.income.str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 16276    True
# 16277    True
# 16278    True
# 16279    True
# 16280    True
# Name: income, Length: 16281, dtype: bool

# %%
dataset[~dataset.income.str.isnumeric()]
# Out:
#        |1x3 Cross validator     work-class  final-weight-estimate  \
# 0                        25        Private                 226802
# 1                        38        Private                  89814
# 2                        28      Local-gov                 336951
# 3                        44        Private                 160323
# 4                        18              ?                 103497
# ...                     ...            ...                    ...
# 16276                    39        Private                 215419
# 16277                    64              ?                 321403
# 16278                    38        Private                 374983
# 16279                    44        Private                  83891
# 16280                    35   Self-emp-inc                 182148
#
#            education  education-num       marital-status          occupation  \
# 0               11th              7        Never-married   Machine-op-inspct
# ...

# %%
dataset[dataset.income.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [|1x3 Cross validator, work-class, final-weight-estimate, education, education-num, marital-status, occupation, realtionship, race, sex, capital-gain, capital-loss, hourse-per-week, native-country, income]
# Index: []

# %%
dataset_copy=dataset.copy()

# %%
dataset_copy.head(2)
# Out:
#    |1x3 Cross validator work-class  final-weight-estimate education  \
# 0                    25    Private                 226802      11th
# 1                    38    Private                  89814   HS-grad
#
#    education-num       marital-status          occupation realtionship  \
# 0              7        Never-married   Machine-op-inspct    Own-child
# 1              9   Married-civ-spouse     Farming-fishing      Husband
#
#      race    sex  capital-gain  capital-loss  hourse-per-week  native-country  \
# 0   Black   Male           0.0             0               40   United-States
# 1   White   Male           0.0             0               50   United-States
#
#        income
# 0   <=501000.
# 1   <=501000.

# %%
dataset_copy['final-weight-estimate'].unique()
# Out:
# array([226802,  89814, 336951, ..., 349230, 321403,  83891], dtype=int64)

# %%
dataset_copy['native-country'].unique()
# Out:
# array([' United-States', ' ?', ' Peru', ' Guatemala', ' Mexico',
#        ' Dominican-Republic', ' Ireland', ' Germany', ' Philippines',
#        ' Thailand', ' Haiti', ' El-Salvador', ' Puerto-Rico', ' Vietnam',
#        ' South', ' Columbia', ' Japan', ' India', ' Cambodia', ' Poland',
#        ' Laos', ' England', ' Cuba', ' Taiwan', ' Italy', ' Canada',
#        ' Portugal', ' China', ' Nicaragua', ' Honduras', ' Iran',
#        ' Scotland', ' Jamaica', ' Ecuador', ' Yugoslavia', ' Hungary',
#        ' Hong', ' Greece', ' Trinadad&Tobago',
#        ' Outlying-US(Guam-USVI-etc)', ' France'], dtype=object)

# %%
dataset_copy['occupation'].unique()
# Out:
# array([' Machine-op-inspct', ' Farming-fishing', ' Protective-serv', ' ?',
#        ' Other-service', ' Prof-specialty', ' Craft-repair',
#        ' Adm-clerical', ' Exec-managerial', ' Tech-support', ' Sales',
#        ' Priv-house-serv', ' Transport-moving', ' Handlers-cleaners',
#        ' Armed-Forces'], dtype=object)

# %%
dataset_copy['income'].unique()
# Out:
# array([' <=501000.', ' >501000.'], dtype=object)

# %%
dataset_copy['income'].dtype
# Out:
# dtype('O')

# %%
dataset_copy['income'].

# %%
dataset_copy['capital-gain'].unique()
# Out:
# array([    0.,  7688.,  3103.,  6418.,  7298.,  3908., 14084.,  5178.,
#        15024., 99999.,  2597.,  2907.,  4650.,  6497.,  1055.,  5013.,
#        27828.,  4934.,  4064.,  3674.,  2174., 10605.,  3418.,   114.,
#         2580.,  3411.,  4508.,  4386.,  8614., 13550.,  6849.,  2463.,
#         3137.,  2885.,  2964.,  1471., 10566.,  2354.,  1424.,  1455.,
#         3325.,  4416., 25236.,   594.,  2105.,  4787.,  2829.,   401.,
#         4865.,  1264.,  1506., 10520.,  3464.,  2653., 20051.,  4101.,
#         1797.,  2407.,  3471.,  1086.,  1848., 14344.,  1151.,  2993.,
#         2290., 15020.,  9386.,  2202.,  3818.,  2176.,  5455., 11678.,
#         7978.,  7262.,  6514., 41310.,  3456.,  7430.,  2414.,  2062.,
#        34095.,  1831.,  6723.,  5060., 15831.,  2977.,  2346.,  3273.,
#         2329.,  9562.,  2635.,  4931.,  1731.,  6097.,   914.,  7896.,
#         5556.,  1409.,  3781.,  3942.,  2538.,  3887., 25124.,  7443.,
# ...

# %%
dataset_copy['capital-gain']=dataset_copy['capital-gain']

# %%
dataset_copy['capital-gain']
# Out:
# 0           0
# 1           0
# 2           0
# 3        7688
# 4           0
#          ...
# 16276       0
# 16277       0
# 16278       0
# 16279    5455
# 16280       0
# Name: capital-gain, Length: 16281, dtype: int64

# %%
dataset_copy['capital-gain']=dataset_copy['capital-gain'].astype('float')

# %%
dataset_copy['capital-gain'].dtype
# Out:
# dtype('float64')

# %%
dataset_copy['income'].str.replace('K','1000')
# Out:
# 0         <=501000.
# 1         <=501000.
# 2          >501000.
# 3          >501000.
# 4         <=501000.
#             ...
# 16276     <=501000.
# 16277     <=501000.
# 16278     <=501000.
# 16279     <=501000.
# 16280      >501000.
# Name: income, Length: 16281, dtype: object

# %%
dataset_copy['income']=dataset_copy['income'].str.replace('K','1000')

# %%
dataset_copy['income'].unique()
# Out:
# array([' <=501000.', ' >501000.'], dtype=object)

# %%
dataset_copy['occupation']=dataset_copy['occupation']

# %%
#if there is any unnecessary words in the data set replace as follows

import numpy as np
dataset_copy['occupation']=dataset_copy['occupation'].replace('?',(np.nan))
dataset_copy['native-country']=dataset_copy['native-country'].replace('?',(np.nan))
dataset_copy['work-class']=dataset_copy['work-class'].replace('?',(np.nan))

# %%
dataset_copy['occupation'].unique()
# Out:
# array([' Machine-op-inspct', ' Farming-fishing', ' Protective-serv',
#        ' nan', ' Other-service', ' Prof-specialty', ' Craft-repair',
#        ' Adm-clerical', ' Exec-managerial', ' Tech-support', ' Sales',
#        ' Priv-house-serv', ' Transport-moving', ' Handlers-cleaners',
#        ' Armed-Forces'], dtype=object)

# %% [markdown]
# #could not convert string to float: eg,' <=501000.',replace < or> =
# import numpy as np
# dataset_copy['income']=dataset_copy['income'].astype('float')

# %%
dataset_copy['income']*100
# Out:
# 0         <=501000. <=501000. <=501000. <=501000. <=501...
# 1         <=501000. <=501000. <=501000. <=501000. <=501...
# 2         >501000. >501000. >501000. >501000. >501000. ...
# 3         >501000. >501000. >501000. >501000. >501000. ...
# 4         <=501000. <=501000. <=501000. <=501000. <=501...
#                                ...
# 16276     <=501000. <=501000. <=501000. <=501000. <=501...
# 16277     <=501000. <=501000. <=501000. <=501000. <=501...
# 16278     <=501000. <=501000. <=501000. <=501000. <=501...
# 16279     <=501000. <=501000. <=501000. <=501000. <=501...
# 16280     >501000. >501000. >501000. >501000. >501000. ...
# Name: income, Length: 16281, dtype: object

# %%
#?=replaced by nan and k=replaced by 1000,cleaned data

dataset_copy.head()
# Out:
#    |1x3 Cross validator  work-class  final-weight-estimate      education  \
# 0                    25     Private                 226802           11th
# 1                    38     Private                  89814        HS-grad
# 2                    28   Local-gov                 336951     Assoc-acdm
# 3                    44     Private                 160323   Some-college
# 4                    18           ?                 103497   Some-college
#
#    education-num       marital-status          occupation realtionship  \
# 0              7        Never-married   Machine-op-inspct    Own-child
# 1              9   Married-civ-spouse     Farming-fishing      Husband
# 2             12   Married-civ-spouse     Protective-serv      Husband
# 3             10   Married-civ-spouse   Machine-op-inspct      Husband
# 4             10        Never-married                 nan    Own-child
#
#      race      sex  capital-gain  capital-loss  hourse-per-week  \
# ...

# %%
#liberaries for EDA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
dataset_copy.columns
# Out:
# Index(['|1x3 Cross validator', 'work-class', 'final-weight-estimate',
#        'education', 'education-num', 'marital-status', 'occupation',
#        'realtionship', 'race', 'sex', 'capital-gain', 'capital-loss',
#        'hourse-per-week', 'native-country', 'income'],
#       dtype='object')

# %%
#one-variant-ONE COLUMNS ANALYSIS,bi-variant-2 COLUMNS,multi-variant->2 for TYPS OF EDA-

# %% [markdown]
# #drop duplicated in phyton
#
# dataset_copy.duplicated()

# %%
#df=dataset_copy.duplicated()

# %%
#df

# %%
#df[dataset_copy.duplicated('income')]

# %%
#df.drop_duplicates()

# %%
#df.drop_duplicates(subset=['income'],keep='first')

# %%
dataset_copy.describe().T
# Out:
#                          count           mean            std      min  \
# |1x3 Cross validator   16281.0      38.767459      13.849187     17.0
# final-weight-estimate  16281.0  189435.677784  105714.907671  13492.0
# education-num          16281.0      10.072907       2.567545      1.0
# capital-gain           16281.0    1081.905104    7583.935968      0.0
# capital-loss           16281.0      87.899269     403.105286      0.0
# hourse-per-week        16281.0      40.392236      12.479332      1.0
#
#                             25%       50%       75%        max
# |1x3 Cross validator       28.0      37.0      48.0       90.0
# final-weight-estimate  116736.0  177831.0  238384.0  1490400.0
# education-num               9.0      10.0      12.0       16.0
# capital-gain                0.0       0.0       0.0    99999.0
# capital-loss                0.0       0.0       0.0     3770.0
# hourse-per-week            40.0      40.0      45.0       99.0

# %%
#segrate the feaature

numeric_features = [feature for feature in dataset_copy.columns if dataset_copy[feature].dtype != 'O']

# %%
dataset_copy[numeric_features]
# Out:
#        |1x3 Cross validator  final-weight-estimate  education-num  \
# 0                        25                 226802              7
# 1                        38                  89814              9
# 2                        28                 336951             12
# 3                        44                 160323             10
# 4                        18                 103497             10
# ...                     ...                    ...            ...
# 16276                    39                 215419             13
# 16277                    64                 321403              9
# 16278                    38                 374983             13
# 16279                    44                  83891             13
# 16280                    35                 182148             13
#
#        capital-gain  capital-loss  hourse-per-week
# 0               0.0             0               40
# 1               0.0             0               50
# ...

# %%
numeric_features
# Out:
# ['|1x3 Cross validator',
#  'final-weight-estimate',
#  'education-num',
#  'capital-gain',
#  'capital-loss',
#  'hourse-per-week']

# %%
categorical_features = [feature for feature in dataset.columns if dataset_copy[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['work-class',
#  'education',
#  'marital-status',
#  'occupation',
#  'realtionship',
#  'race',
#  'sex',
#  'native-country',
#  'income']

# %%
dataset_copy[categorical_features]
# Out:
#           work-class      education       marital-status          occupation  \
# 0            Private           11th        Never-married   Machine-op-inspct
# 1            Private        HS-grad   Married-civ-spouse     Farming-fishing
# 2          Local-gov     Assoc-acdm   Married-civ-spouse     Protective-serv
# 3            Private   Some-college   Married-civ-spouse   Machine-op-inspct
# 4                  ?   Some-college        Never-married                 nan
# ...              ...            ...                  ...                 ...
# 16276        Private      Bachelors             Divorced      Prof-specialty
# 16277              ?        HS-grad              Widowed                 nan
# 16278        Private      Bachelors   Married-civ-spouse      Prof-specialty
# 16279        Private      Bachelors             Divorced        Adm-clerical
# 16280   Self-emp-inc      Bachelors   Married-civ-spouse     Exec-managerial
#
# ...

# %%
#replace ?

# %%
#value counts for categorical variables,%age ,eg

dataset_copy['sex']
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4         Female
#           ...
# 16276     Female
# 16277       Male
# 16278       Male
# 16279       Male
# 16280       Male
# Name: sex, Length: 16281, dtype: object

# %%
dataset_copy['sex'].value_counts()
# Out:
#  Male      10860
#  Female     5421
# Name: sex, dtype: int64

# %%
dataset_copy['sex'].value_counts(normalize=True)
# Out:
#  Male      0.667035
#  Female    0.332965
# Name: sex, dtype: float64

# %%
dataset_copy['sex'].value_counts(normalize=True)*100
# Out:
#  Male      66.703519
#  Female    33.296481
# Name: sex, dtype: float64

# %%
for col in categorical_features:
    print(f"{col}:{dataset_copy[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# work-class: Private             68.853265
#  Self-emp-not-inc     8.113752
#  Local-gov            6.406240
#  ?                    5.914870
#  State-gov            4.195074
#  Self-emp-inc         3.556293
#  Federal-gov          2.899085
#  Without-pay          0.042995
#  Never-worked         0.018426
# Name: work-class, dtype: float64
# ...
# education: HS-grad         32.448867
#  Some-college    22.031816
#  Bachelors       16.399484
#  Masters          5.736748
#  Assoc-voc        4.170505
#  11th             3.912536
#  Assoc-acdm       3.279897
#  10th             2.800811
#  7th-8th          1.897918
#  Prof-school      1.584669
#  9th              1.486395
#  12th             1.375837
#  Doctorate        1.111725
#  5th-6th          1.081015
#  1st-4th          0.485228
#  Preschool        0.196548
# Name: education, dtype: float64
# ...
# marital-status: Married-civ-spouse       45.470180
#  Never-married            33.376328
#  Divorced                 13.451262
# ...

# %%
#category = [ 'education', 'income'] wise count plot
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold',
alpha=0.8, y=1.)
category = [ 'education', 'income']
for i in range(0, len(category)):
plt.subplot(2, 2, i+1)
sns.countplot(x=dataset_copy[category[i]],palette="Set2")
plt.xlabel(category[i])
plt.xticks(rotation=45)
plt.tight_layout()
# Out:
#   File "C:\Users\alemnew\AppData\Local\Temp\ipykernel_16860\2157994457.py", line 8
#     plt.subplot(2, 2, i+1)
#     ^
# IndentationError: expected an indented block

# %%
#high number in percentage in education category--univariant analysis

dataset_copy['education'].value_counts().plots()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16860\3613992861.py in <module>
# ----> 1 dataset_copy['education'].value_counts().plots.pie()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'plots'

# %%
dataset_copy['education'].value_counts()
# Out:
#  HS-grad         5283
#  Some-college    3587
#  Bachelors       2670
#  Masters          934
#  Assoc-voc        679
#  11th             637
#  Assoc-acdm       534
#  10th             456
#  7th-8th          309
#  Prof-school      258
#  9th              242
#  12th             224
#  Doctorate        181
#  5th-6th          176
#  1st-4th           79
#  Preschool         32
# Name: education, dtype: int64

# %%
dataset_copy['education'].value_counts().plots.pie()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16860\3613992861.py in <module>
# ----> 1 dataset_copy['education'].value_counts().plots.pie()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'plots'

# %%
dataset_copy['education'].value_counts().plots.pie(y=dataset-copy['education'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16860\1501635386.py in <module>
# ----> 1 dataset_copy['education'].value_counts().plots.pie(y=dataset-copy['education'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'plots'

# %%
dataset_copy['education'].value_counts().plots.pie(y=dataset-copy['education'],figsize=(15,15),autopic='1%,1f%%'')
# Out:
#   File "C:\Users\alemnew\AppData\Local\Temp\ipykernel_16860\186414419.py", line 1
#     dataset_copy['education'].value_counts().plots.pie(y=dataset-copy['education'],figsize=(15,15),autopic='1%,1f%%'')
#                                                                                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
#top ten from education
dataset_copy['education'].value_counts()[:10]
# Out:
#  HS-grad         5283
#  Some-college    3587
#  Bachelors       2670
#  Masters          934
#  Assoc-voc        679
#  11th             637
#  Assoc-acdm       534
#  10th             456
#  7th-8th          309
#  Prof-school      258
# Name: education, dtype: int64

# %%
df_edu=sns.barplot(dataset_copy['education'].value_counts()[:10])

# %%
#Dataframe of apps on
the basis of category

df_edu['education']
# Out:
#   File "C:\Users\alemnew\AppData\Local\Temp\ipykernel_16860\1977343563.py", line 2
#     the basis of category
#         ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_edu, y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16860\1469920714.py in <module>
#       1 plt.figure(figsize=(15,6))
# ----> 2 sns.barplot(x=df_edu, y ='Count',data = category[:10],palette='hls')
#       3 plt.title('Top 10 App categories')
#       4 plt.xticks(rotation=90)
#       5 plt.show()
#
# NameError: name 'category' is not defined
